# %% [markdown]
# # DML 코드 practice
#
# ### dataset : CIFAR100
# ### Teacher model : MobileNet
# ### Student model : ResNet32
# ### Ditillation method : DML (Deep mutual Learning)

# %% [markdown]
# # step 1 : 필요한 라이브러리 로드

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm  # Ensure you are importing the function from the module

# %% [markdown]
# # Step 2 : CIFAR100 데이터셋 로드

# %%
# Data augmentation and normalization for training set
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
])

# Only normalization for test set
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761))
])

# Download CIFAR-100 dataset
train_dataset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=8)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=8)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # step 3 : Model definition

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# For reproducibility
torch.manual_seed(42)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# BasicBlock 클래스 정의 (ResNet의 기본 구성 요소)
class BasicBlock(nn.Module):
    expansion = 1  # 확장 계수 (필터의 크기를 변경하는 데 사용)

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        # 첫 번째 3x3 컨볼루션 레이어: 입력 채널(in_planes) -> 출력 채널(planes), stride와 padding 설정
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)  # 첫 번째 Batch Normalization 레이어
        # 두 번째 3x3 컨볼루션 레이어: 출력 채널 유지
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)  # 두 번째 Batch Normalization 레이어

        # Shortcut 경로: 입력과 출력의 크기가 다르면 크기를 조정하는 레이어 추가
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:  # 크기 또는 채널 수가 다를 경우
            self.shortcut = nn.Sequential(
                # 1x1 컨볼루션: 입력 채널(in_planes) -> 출력 채널(planes * expansion), stride 적용
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes)  # Batch Normalization
            )

    def forward(self, x):
        # 입력 데이터에 대해 첫 번째 컨볼루션과 ReLU 활성화 함수 적용
        out = F.relu(self.bn1(self.conv1(x)))
        # 두 번째 컨볼루션 및 Batch Normalization 적용
        out = self.bn2(self.conv2(out))
        # Shortcut 경로를 통해 입력과 현재 출력 더하기
        out += self.shortcut(x)
        # 다시 ReLU 활성화 함수 적용
        out = F.relu(out)
        return out


# ResNet32 모델 정의
class ResNet32(nn.Module):
    def __init__(self, num_classes=100):
        super(ResNet32, self).__init__()
        self.in_planes = 16  # 입력 채널 크기 초기화

        # 첫 번째 컨볼루션 레이어와 Batch Normalization
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)  # 3채널(RGB) -> 16채널로 변환
        self.bn1 = nn.BatchNorm2d(16)

        # 세 개의 레이어 블록 생성 (각 블록은 여러 BasicBlock으로 구성)
        # layer1: 채널 16 유지, 5개의 블록, stride=1
        self.layer1 = self._make_layer(BasicBlock, 16, 5, stride=1)
        # layer2: 채널 32로 증가, 5개의 블록, stride=2 (공간 크기 절반으로 감소)
        self.layer2 = self._make_layer(BasicBlock, 32, 5, stride=2)
        # layer3: 채널 64로 증가, 5개의 블록, stride=2
        self.layer3 = self._make_layer(BasicBlock, 64, 5, stride=2)

        # Adaptive Average Pooling (출력 크기를 1x1로 조정)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # Fully Connected 레이어 (64채널 -> 클래스 수(num_classes) 출력)
        self.fc = nn.Linear(64 * BasicBlock.expansion, num_classes)

    # 블록 생성 함수: 특정 채널 크기와 블록 수로 BasicBlock을 연결
    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)  # 첫 블록만 stride 적용
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))  # BasicBlock 추가
            self.in_planes = planes * block.expansion  # 다음 블록의 입력 크기 업데이트
        return nn.Sequential(*layers)

    def forward(self, x):
        # 첫 번째 컨볼루션과 BatchNorm
        out = F.relu(self.bn1(self.conv1(x)))
        # 세 개의 레이어 블록 통과
        out = self.layer1(out)  # 첫 번째 레이어 블록
        out = self.layer2(out)  # 두 번째 레이어 블록
        out = self.layer3(out)  # 세 번째 레이어 블록
        # Adaptive Average Pooling 적용
        out = self.avgpool(out)
        # 1D 벡터로 변환
        out = out.view(out.size(0), -1)
        # Fully Connected 레이어로 출력
        out = self.fc(out)
        return out


# 모델 초기화
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # GPU 사용 여부 확인

# MobileNetV2 모델 로드 (PyTorch의 미리 학습된 모델 사용)
mobilenet_model = torch.hub.load('pytorch/vision:v0.10.0', 'mobilenet_v2', num_classes=100).to(device)

# ResNet32 모델 인스턴스 생성
resnet32_model = ResNet32(num_classes=100).to(device)

# 모델 정보 출력
print(mobilenet_model)  # MobileNetV2 구조 출력
print(resnet32_model)   # ResNet32 구조 출력
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=100, bias=True)
#   )
# )
# ResNet32(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=64, out_features=100, bias=True)
# )
# Using cache found in /home/park/.cache/torch/hub/pytorch_vision_v0.10.0

# %% [markdown]
# # step 4 : loss function & optimizer 정의

# %%
# Cross-entropy loss
criterion = nn.CrossEntropyLoss()

# Optimizers for both models
optimizer_mobile = optim.Adam(mobilenet_model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=5e-4)
optimizer_resnet = optim.Adam(resnet32_model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=5e-4)

# Learning rate scheduler
scheduler_mobile = optim.lr_scheduler.StepLR(optimizer_mobile, step_size=30, gamma=0.01)
scheduler_resnet = optim.lr_scheduler.StepLR(optimizer_resnet, step_size=30, gamma=0.01)

# %% [markdown]
# # step 5 : DML & Loss function

# %%
def mutual_learning_loss(output1, output2):
    kl_loss = nn.KLDivLoss(reduction='batchmean')
    return kl_loss(nn.functional.log_softmax(output1, dim=1), nn.functional.softmax(output2, dim=1)) + \
           kl_loss(nn.functional.log_softmax(output2, dim=1), nn.functional.softmax(output1, dim=1))

# %% [markdown]
# # step 6 : ResNet32 before distillation

# %%
def train_resnet32(epoch, model, optimizer):
    model.train()
    
    total_loss = 0
    correct = 0
    total = 0
    
    progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f'Epoch {epoch}')
    
    for batch_idx, (inputs, targets) in progress_bar:
        inputs, targets = inputs.to(device), targets.to(device)
        
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        
        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Statistics
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        total_loss += loss.item()
        
        progress_bar.set_postfix({
            'Loss': f'{total_loss/(batch_idx+1):.4f}',
            'Accuracy': f'{correct/total*100:.2f}%'
        })
# Evaluation function for ResNet32
def test_resnet32(epoch, model):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    criterion = nn.CrossEntropyLoss()
    progress_bar = tqdm(enumerate(test_loader), total=len(test_loader), desc=f"Epoch {epoch} [Testing ResNet32]")

    with torch.no_grad():
        for batch_idx, (inputs, targets) in progress_bar:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

            progress_bar.set_postfix({
                'Test Loss': f'{test_loss/(batch_idx+1):.4f}',
                'Accuracy': f'{correct/total*100:.2f}%'
            })
    
    return correct, total

# %% [markdown]
# # step 7 : training MobileNet and ResNet32 with DML

# %%
def train(epoch, model1, model2, optimizer1, optimizer2):
    model1.train()
    model2.train()
    
    total_loss1, total_loss2 = 0, 0
    correct1, correct2 = 0, 0
    total = 0
    
    progress_bar = tqdm(enumerate(train_loader), total=len(train_loader), desc=f'Epoch {epoch}')
    
    for batch_idx, (inputs, targets) in progress_bar:
        inputs, targets = inputs.to(device), targets.to(device)
        
        # Forward pass
        outputs1 = model1(inputs)
        outputs2 = model2(inputs)
        
        # Loss calculation
        loss1 = criterion(outputs1, targets)
        loss2 = criterion(outputs2, targets)
        ml_loss = mutual_learning_loss(outputs1, outputs2)
        
        total_loss = loss1 + loss2 + ml_loss
        
        # Backpropagation
        optimizer1.zero_grad()
        optimizer2.zero_grad()
        total_loss.backward()
        
        # Optimizer step
        optimizer1.step()
        optimizer2.step()
        
        # Statistics
        _, predicted1 = outputs1.max(1)
        _, predicted2 = outputs2.max(1)
        
        total += targets.size(0)
        correct1 += predicted1.eq(targets).sum().item()
        correct2 += predicted2.eq(targets).sum().item()
        
        total_loss1 += loss1.item()
        total_loss2 += loss2.item()
        
        # Update progress bar with current statistics
        progress_bar.set_postfix({
            'MobileNet Loss': f'{total_loss1/(batch_idx+1):.4f}',
            'ResNet32 Loss': f'{total_loss2/(batch_idx+1):.4f}',
            'MobileNet Acc': f'{correct1/total*100:.2f}%',
            'ResNet32 Acc': f'{correct2/total*100:.2f}%'
        })

# %% [markdown]
# # step 7 : testing loop

# %%
def test(epoch, model):
    model.eval()
    correct = 0
    total = 0
    test_loss = 0
    
    progress_bar = tqdm(enumerate(test_loader), total=len(test_loader), desc=f'Test Epoch {epoch}')
    
    with torch.no_grad():
        for batch_idx, (inputs, targets) in progress_bar:
            inputs, targets = inputs.to(device), targets.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
            
            # Update progress bar with current statistics
            progress_bar.set_postfix({
                'Test Loss': f'{test_loss/(batch_idx+1):.4f}',
                'Accuracy': f'{correct/total*100:.2f}%'
            })

# %%
# Step 1: Train ResNet32 Independently (Before Distillation)
resnet32_model_independent = ResNet32(num_classes=100).to(device)
optimizer_resnet_independent = optim.SGD(resnet32_model_independent.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4)
scheduler_resnet_independent = optim.lr_scheduler.StepLR(optimizer_resnet_independent, step_size=30, gamma=0.1)

print("Training ResNet32 before distillation...")
for epoch in range(150):
    train_resnet32(epoch, resnet32_model_independent, optimizer_resnet_independent)
    correct, total = test_resnet32(epoch, resnet32_model_independent)
    scheduler_resnet_independent.step()

# Store the final accuracy of the independent ResNet32
resnet32_independent_accuracy = correct / total * 100
# Step 2: Train MobileNet and ResNet32 with DML (After Distillation)
print("Training MobileNet and ResNet32 with DML...")
for epoch in range(150):
    train(epoch, mobilenet_model, resnet32_model, optimizer_mobile, optimizer_resnet)
    correct, total = test_resnet32(epoch, resnet32_model)  # Evaluate ResNet32 after DML
    scheduler_mobile.step()
    scheduler_resnet.step()

# Store the final accuracy of the ResNet32 after DML
resnet32_dml_accuracy = correct / total * 100

# Print comparison of the independent ResNet32 and the DML-trained ResNet32
print(f'Accuracy Comparison:\nResNet32 Independent: {resnet32_independent_accuracy:.2f}%\nResNet32 after DML: {resnet32_dml_accuracy:.2f}%')
# Out:
# Training ResNet32 before distillation...
# Epoch 0: 100%|██████████| 391/391 [00:03<00:00, 102.48it/s, Loss=4.4115, Accuracy=4.15%]
# Epoch 0 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 276.55it/s, Test Loss=4.1783, Accuracy=6.20%]
# Epoch 1: 100%|██████████| 391/391 [00:03<00:00, 108.48it/s, Loss=4.0208, Accuracy=8.76%]
# Epoch 1 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 334.44it/s, Test Loss=3.8520, Accuracy=11.30%]
# Epoch 2: 100%|██████████| 391/391 [00:03<00:00, 105.41it/s, Loss=3.7660, Accuracy=12.03%]
# Epoch 2 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 292.17it/s, Test Loss=3.6618, Accuracy=14.12%]
# Epoch 3: 100%|██████████| 391/391 [00:03<00:00, 109.23it/s, Loss=3.5948, Accuracy=14.72%]
# Epoch 3 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 321.20it/s, Test Loss=3.5048, Accuracy=16.29%]
# Epoch 4: 100%|██████████| 391/391 [00:03<00:00, 106.47it/s, Loss=3.4512, Accuracy=16.94%]
# Epoch 4 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 307.51it/s, Test Loss=3.4178, Accuracy=17.31%]
# Epoch 5: 100%|██████████| 391/391 [00:03<00:00, 105.02it/s, Loss=3.3252, Accuracy=19.09%]
# Epoch 5 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 310.16it/s, Test Loss=3.3175, Accuracy=18.51%]
# Epoch 6: 100%|██████████| 391/391 [00:03<00:00, 108.11it/s, Loss=3.2103, Accuracy=21.18%]
# Epoch 6 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 275.72it/s, Test Loss=3.2507, Accuracy=20.77%]
# Epoch 7: 100%|██████████| 391/391 [00:03<00:00, 106.95it/s, Loss=3.0861, Accuracy=23.38%]
# Epoch 7 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 312.70it/s, Test Loss=3.1284, Accuracy=22.80%]
# Epoch 8: 100%|██████████| 391/391 [00:03<00:00, 106.93it/s, Loss=2.9789, Accuracy=25.45%]
# Epoch 8 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 334.28it/s, Test Loss=2.9719, Accuracy=25.29%]
# Epoch 9: 100%|██████████| 391/391 [00:03<00:00, 105.98it/s, Loss=2.8711, Accuracy=27.24%]
# Epoch 9 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 304.78it/s, Test Loss=2.9094, Accuracy=26.42%]
# Epoch 10: 100%|██████████| 391/391 [00:03<00:00, 105.31it/s, Loss=2.7807, Accuracy=29.18%]
# Epoch 10 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 315.58it/s, Test Loss=2.7249, Accuracy=29.85%]
# Epoch 11: 100%|██████████| 391/391 [00:03<00:00, 106.31it/s, Loss=2.6924, Accuracy=30.63%]
# Epoch 11 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 264.50it/s, Test Loss=2.7395, Accuracy=30.41%]
# Epoch 12: 100%|██████████| 391/391 [00:03<00:00, 105.17it/s, Loss=2.6192, Accuracy=32.29%]
# Epoch 12 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 305.38it/s, Test Loss=2.6593, Accuracy=31.10%]
# Epoch 13: 100%|██████████| 391/391 [00:03<00:00, 106.47it/s, Loss=2.5391, Accuracy=33.74%]
# Epoch 13 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 283.32it/s, Test Loss=2.6048, Accuracy=31.97%]
# Epoch 14: 100%|██████████| 391/391 [00:03<00:00, 106.19it/s, Loss=2.4816, Accuracy=34.71%]
# Epoch 14 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 301.96it/s, Test Loss=2.5831, Accuracy=33.11%]
# Epoch 15: 100%|██████████| 391/391 [00:03<00:00, 108.25it/s, Loss=2.4159, Accuracy=36.21%]
# Epoch 15 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 278.52it/s, Test Loss=2.4763, Accuracy=34.42%]
# Epoch 16: 100%|██████████| 391/391 [00:03<00:00, 104.95it/s, Loss=2.3611, Accuracy=37.47%]
# Epoch 16 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 300.96it/s, Test Loss=2.4896, Accuracy=35.33%]
# Epoch 17: 100%|██████████| 391/391 [00:03<00:00, 107.15it/s, Loss=2.3046, Accuracy=38.83%]
# Epoch 17 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 270.86it/s, Test Loss=2.4118, Accuracy=35.73%]
# Epoch 18: 100%|██████████| 391/391 [00:03<00:00, 106.78it/s, Loss=2.2540, Accuracy=39.79%]
# Epoch 18 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 284.84it/s, Test Loss=2.3264, Accuracy=38.11%]
# Epoch 19: 100%|██████████| 391/391 [00:03<00:00, 105.19it/s, Loss=2.1988, Accuracy=40.92%]
# Epoch 19 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 276.83it/s, Test Loss=2.3222, Accuracy=38.24%]
# Epoch 20: 100%|██████████| 391/391 [00:03<00:00, 104.43it/s, Loss=2.1514, Accuracy=42.13%]
# Epoch 20 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 324.27it/s, Test Loss=2.2955, Accuracy=39.07%]
# Epoch 21: 100%|██████████| 391/391 [00:03<00:00, 105.87it/s, Loss=2.1109, Accuracy=42.99%]
# Epoch 21 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.20it/s, Test Loss=2.1889, Accuracy=40.93%]
# Epoch 22: 100%|██████████| 391/391 [00:03<00:00, 106.77it/s, Loss=2.0732, Accuracy=43.87%]
# Epoch 22 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 314.59it/s, Test Loss=2.2482, Accuracy=40.34%]
# Epoch 23: 100%|██████████| 391/391 [00:03<00:00, 105.54it/s, Loss=2.0243, Accuracy=45.00%]
# Epoch 23 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 286.20it/s, Test Loss=2.1265, Accuracy=42.52%]
# Epoch 24: 100%|██████████| 391/391 [00:03<00:00, 105.62it/s, Loss=1.9825, Accuracy=46.22%]
# Epoch 24 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 281.39it/s, Test Loss=2.1070, Accuracy=42.52%]
# Epoch 25: 100%|██████████| 391/391 [00:03<00:00, 105.75it/s, Loss=1.9421, Accuracy=47.06%]
# Epoch 25 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 337.56it/s, Test Loss=2.0730, Accuracy=44.30%]
# Epoch 26: 100%|██████████| 391/391 [00:03<00:00, 107.42it/s, Loss=1.9092, Accuracy=47.74%]
# Epoch 26 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 315.92it/s, Test Loss=2.0858, Accuracy=43.14%]
# Epoch 27: 100%|██████████| 391/391 [00:03<00:00, 105.87it/s, Loss=1.8724, Accuracy=48.60%]
# Epoch 27 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 292.00it/s, Test Loss=2.0566, Accuracy=44.27%]
# Epoch 28: 100%|██████████| 391/391 [00:03<00:00, 107.18it/s, Loss=1.8500, Accuracy=49.12%]
# Epoch 28 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 301.09it/s, Test Loss=2.0724, Accuracy=44.03%]
# Epoch 29: 100%|██████████| 391/391 [00:03<00:00, 105.75it/s, Loss=1.8167, Accuracy=49.73%]
# Epoch 29 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 291.09it/s, Test Loss=2.0348, Accuracy=45.39%]
# Epoch 30: 100%|██████████| 391/391 [00:03<00:00, 107.95it/s, Loss=1.6931, Accuracy=53.17%]
# Epoch 30 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 298.15it/s, Test Loss=1.7985, Accuracy=50.32%]
# Epoch 31: 100%|██████████| 391/391 [00:03<00:00, 105.04it/s, Loss=1.6601, Accuracy=54.03%]
# Epoch 31 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 286.53it/s, Test Loss=1.7867, Accuracy=50.64%]
# Epoch 32: 100%|██████████| 391/391 [00:03<00:00, 104.83it/s, Loss=1.6477, Accuracy=54.38%]
# Epoch 32 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 297.26it/s, Test Loss=1.7844, Accuracy=50.85%]
# Epoch 33: 100%|██████████| 391/391 [00:03<00:00, 106.61it/s, Loss=1.6449, Accuracy=54.61%]
# Epoch 33 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 330.79it/s, Test Loss=1.7827, Accuracy=50.95%]
# Epoch 34: 100%|██████████| 391/391 [00:03<00:00, 107.87it/s, Loss=1.6442, Accuracy=54.36%]
# Epoch 34 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 278.98it/s, Test Loss=1.7759, Accuracy=51.23%]
# Epoch 35: 100%|██████████| 391/391 [00:03<00:00, 106.99it/s, Loss=1.6359, Accuracy=54.52%]
# Epoch 35 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 288.65it/s, Test Loss=1.7767, Accuracy=51.06%]
# Epoch 36: 100%|██████████| 391/391 [00:03<00:00, 102.76it/s, Loss=1.6288, Accuracy=54.88%]
# Epoch 36 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 317.30it/s, Test Loss=1.7752, Accuracy=51.41%]
# Epoch 37: 100%|██████████| 391/391 [00:03<00:00, 105.47it/s, Loss=1.6246, Accuracy=54.85%]
# Epoch 37 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 291.69it/s, Test Loss=1.7781, Accuracy=51.03%]
# Epoch 38: 100%|██████████| 391/391 [00:03<00:00, 106.53it/s, Loss=1.6203, Accuracy=54.95%]
# Epoch 38 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 280.34it/s, Test Loss=1.7718, Accuracy=51.40%]
# Epoch 39: 100%|██████████| 391/391 [00:03<00:00, 107.92it/s, Loss=1.6124, Accuracy=55.14%]
# Epoch 39 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 326.27it/s, Test Loss=1.7768, Accuracy=51.05%]
# Epoch 40: 100%|██████████| 391/391 [00:03<00:00, 106.01it/s, Loss=1.6121, Accuracy=55.12%]
# Epoch 40 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 295.06it/s, Test Loss=1.7745, Accuracy=51.19%]
# Epoch 41: 100%|██████████| 391/391 [00:03<00:00, 106.38it/s, Loss=1.6049, Accuracy=55.24%]
# Epoch 41 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 292.81it/s, Test Loss=1.7764, Accuracy=51.19%]
# Epoch 42: 100%|██████████| 391/391 [00:03<00:00, 108.46it/s, Loss=1.6021, Accuracy=55.29%]
# Epoch 42 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 294.90it/s, Test Loss=1.7634, Accuracy=51.27%]
# Epoch 43: 100%|██████████| 391/391 [00:03<00:00, 106.63it/s, Loss=1.5957, Accuracy=55.53%]
# Epoch 43 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 277.62it/s, Test Loss=1.7624, Accuracy=51.54%]
# Epoch 44: 100%|██████████| 391/391 [00:03<00:00, 104.25it/s, Loss=1.5924, Accuracy=55.71%]
# Epoch 44 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 255.33it/s, Test Loss=1.7555, Accuracy=51.44%]
# Epoch 45: 100%|██████████| 391/391 [00:03<00:00, 107.31it/s, Loss=1.5856, Accuracy=55.87%]
# Epoch 45 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.17it/s, Test Loss=1.7567, Accuracy=51.55%]
# Epoch 46: 100%|██████████| 391/391 [00:03<00:00, 106.30it/s, Loss=1.5849, Accuracy=55.83%]
# Epoch 46 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 297.17it/s, Test Loss=1.7621, Accuracy=51.44%]
# Epoch 47: 100%|██████████| 391/391 [00:03<00:00, 107.17it/s, Loss=1.5808, Accuracy=55.90%]
# Epoch 47 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.47it/s, Test Loss=1.7599, Accuracy=51.79%]
# Epoch 48: 100%|██████████| 391/391 [00:03<00:00, 105.29it/s, Loss=1.5729, Accuracy=55.89%]
# Epoch 48 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 264.38it/s, Test Loss=1.7557, Accuracy=51.84%]
# Epoch 49: 100%|██████████| 391/391 [00:03<00:00, 107.55it/s, Loss=1.5707, Accuracy=56.30%]
# Epoch 49 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 269.94it/s, Test Loss=1.7509, Accuracy=51.88%]
# Epoch 50: 100%|██████████| 391/391 [00:03<00:00, 106.31it/s, Loss=1.5705, Accuracy=56.07%]
# Epoch 50 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 272.19it/s, Test Loss=1.7571, Accuracy=51.80%]
# Epoch 51: 100%|██████████| 391/391 [00:03<00:00, 103.83it/s, Loss=1.5647, Accuracy=56.37%]
# Epoch 51 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 266.12it/s, Test Loss=1.7549, Accuracy=51.78%]
# Epoch 52: 100%|██████████| 391/391 [00:03<00:00, 105.63it/s, Loss=1.5568, Accuracy=56.67%]
# Epoch 52 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 285.80it/s, Test Loss=1.7478, Accuracy=51.67%]
# Epoch 53: 100%|██████████| 391/391 [00:03<00:00, 105.20it/s, Loss=1.5623, Accuracy=56.22%]
# Epoch 53 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 319.94it/s, Test Loss=1.7513, Accuracy=51.76%]
# Epoch 54: 100%|██████████| 391/391 [00:03<00:00, 104.00it/s, Loss=1.5533, Accuracy=56.36%]
# Epoch 54 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 299.81it/s, Test Loss=1.7417, Accuracy=52.11%]
# Epoch 55: 100%|██████████| 391/391 [00:03<00:00, 105.61it/s, Loss=1.5472, Accuracy=56.87%]
# Epoch 55 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 290.40it/s, Test Loss=1.7453, Accuracy=52.07%]
# Epoch 56: 100%|██████████| 391/391 [00:03<00:00, 104.64it/s, Loss=1.5463, Accuracy=56.65%]
# Epoch 56 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 283.56it/s, Test Loss=1.7436, Accuracy=51.96%]
# Epoch 57: 100%|██████████| 391/391 [00:03<00:00, 105.26it/s, Loss=1.5440, Accuracy=56.84%]
# Epoch 57 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 265.75it/s, Test Loss=1.7421, Accuracy=52.06%]
# Epoch 58: 100%|██████████| 391/391 [00:03<00:00, 105.45it/s, Loss=1.5372, Accuracy=56.80%]
# Epoch 58 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.18it/s, Test Loss=1.7369, Accuracy=52.21%]
# Epoch 59: 100%|██████████| 391/391 [00:03<00:00, 103.47it/s, Loss=1.5326, Accuracy=57.15%]
# Epoch 59 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 254.96it/s, Test Loss=1.7426, Accuracy=52.31%]
# Epoch 60: 100%|██████████| 391/391 [00:03<00:00, 105.25it/s, Loss=1.5209, Accuracy=57.54%]
# Epoch 60 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 257.53it/s, Test Loss=1.7305, Accuracy=52.59%]
# Epoch 61: 100%|██████████| 391/391 [00:03<00:00, 104.04it/s, Loss=1.5144, Accuracy=57.64%]
# Epoch 61 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.76it/s, Test Loss=1.7327, Accuracy=52.38%]
# Epoch 62: 100%|██████████| 391/391 [00:03<00:00, 103.49it/s, Loss=1.5167, Accuracy=57.54%]
# Epoch 62 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 302.51it/s, Test Loss=1.7308, Accuracy=52.42%]
# Epoch 63: 100%|██████████| 391/391 [00:03<00:00, 104.16it/s, Loss=1.5129, Accuracy=57.56%]
# Epoch 63 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 276.15it/s, Test Loss=1.7284, Accuracy=52.45%]
# Epoch 64: 100%|██████████| 391/391 [00:03<00:00, 103.71it/s, Loss=1.5140, Accuracy=57.64%]
# Epoch 64 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 307.91it/s, Test Loss=1.7279, Accuracy=52.43%]
# Epoch 65: 100%|██████████| 391/391 [00:03<00:00, 104.90it/s, Loss=1.5129, Accuracy=57.66%]
# Epoch 65 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 320.33it/s, Test Loss=1.7291, Accuracy=52.53%]
# Epoch 66: 100%|██████████| 391/391 [00:03<00:00, 103.74it/s, Loss=1.5110, Accuracy=57.70%]
# Epoch 66 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 276.94it/s, Test Loss=1.7281, Accuracy=52.46%]
# Epoch 67: 100%|██████████| 391/391 [00:03<00:00, 103.95it/s, Loss=1.5077, Accuracy=57.66%]
# Epoch 67 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 286.51it/s, Test Loss=1.7256, Accuracy=52.54%]
# Epoch 68: 100%|██████████| 391/391 [00:03<00:00, 103.73it/s, Loss=1.5106, Accuracy=57.71%]
# Epoch 68 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 321.23it/s, Test Loss=1.7260, Accuracy=52.71%]
# Epoch 69: 100%|██████████| 391/391 [00:03<00:00, 105.56it/s, Loss=1.5109, Accuracy=57.73%]
# Epoch 69 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 237.35it/s, Test Loss=1.7270, Accuracy=52.65%]
# Epoch 70: 100%|██████████| 391/391 [00:03<00:00, 103.67it/s, Loss=1.5099, Accuracy=57.78%]
# Epoch 70 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 274.98it/s, Test Loss=1.7272, Accuracy=52.58%]
# Epoch 71: 100%|██████████| 391/391 [00:03<00:00, 106.61it/s, Loss=1.5116, Accuracy=57.71%]
# Epoch 71 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 280.90it/s, Test Loss=1.7244, Accuracy=52.48%]
# Epoch 72: 100%|██████████| 391/391 [00:03<00:00, 105.86it/s, Loss=1.5121, Accuracy=57.65%]
# Epoch 72 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 268.79it/s, Test Loss=1.7243, Accuracy=52.62%]
# Epoch 73: 100%|██████████| 391/391 [00:03<00:00, 105.04it/s, Loss=1.5084, Accuracy=57.67%]
# Epoch 73 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 292.15it/s, Test Loss=1.7246, Accuracy=52.65%]
# Epoch 74: 100%|██████████| 391/391 [00:03<00:00, 104.81it/s, Loss=1.5105, Accuracy=57.62%]
# Epoch 74 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 301.11it/s, Test Loss=1.7252, Accuracy=52.50%]
# Epoch 75: 100%|██████████| 391/391 [00:03<00:00, 101.83it/s, Loss=1.5102, Accuracy=57.61%]
# Epoch 75 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 260.92it/s, Test Loss=1.7252, Accuracy=52.57%]
# Epoch 76: 100%|██████████| 391/391 [00:03<00:00, 104.65it/s, Loss=1.5095, Accuracy=57.73%]
# Epoch 76 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.44it/s, Test Loss=1.7236, Accuracy=52.77%]
# Epoch 77: 100%|██████████| 391/391 [00:03<00:00, 106.28it/s, Loss=1.5085, Accuracy=57.73%]
# Epoch 77 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 292.13it/s, Test Loss=1.7246, Accuracy=52.79%]
# Epoch 78: 100%|██████████| 391/391 [00:03<00:00, 105.11it/s, Loss=1.5094, Accuracy=57.87%]
# Epoch 78 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 283.46it/s, Test Loss=1.7248, Accuracy=52.60%]
# Epoch 79: 100%|██████████| 391/391 [00:03<00:00, 105.77it/s, Loss=1.5073, Accuracy=57.80%]
# Epoch 79 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 301.29it/s, Test Loss=1.7285, Accuracy=52.37%]
# Epoch 80: 100%|██████████| 391/391 [00:03<00:00, 105.01it/s, Loss=1.5056, Accuracy=57.70%]
# Epoch 80 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 283.52it/s, Test Loss=1.7237, Accuracy=52.63%]
# Epoch 81: 100%|██████████| 391/391 [00:03<00:00, 103.69it/s, Loss=1.5049, Accuracy=57.56%]
# Epoch 81 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 282.18it/s, Test Loss=1.7226, Accuracy=52.74%]
# Epoch 82: 100%|██████████| 391/391 [00:03<00:00, 103.93it/s, Loss=1.5082, Accuracy=57.79%]
# Epoch 82 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 297.72it/s, Test Loss=1.7245, Accuracy=52.57%]
# Epoch 83: 100%|██████████| 391/391 [00:03<00:00, 105.56it/s, Loss=1.5054, Accuracy=57.65%]
# Epoch 83 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 306.41it/s, Test Loss=1.7271, Accuracy=52.47%]
# Epoch 84: 100%|██████████| 391/391 [00:03<00:00, 106.01it/s, Loss=1.5086, Accuracy=57.92%]
# Epoch 84 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 305.78it/s, Test Loss=1.7242, Accuracy=52.78%]
# Epoch 85: 100%|██████████| 391/391 [00:03<00:00, 104.11it/s, Loss=1.5059, Accuracy=57.87%]
# Epoch 85 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 339.77it/s, Test Loss=1.7324, Accuracy=52.44%]
# Epoch 86: 100%|██████████| 391/391 [00:03<00:00, 106.65it/s, Loss=1.5021, Accuracy=58.01%]
# Epoch 86 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.63it/s, Test Loss=1.7250, Accuracy=52.71%]
# Epoch 87: 100%|██████████| 391/391 [00:03<00:00, 103.87it/s, Loss=1.5030, Accuracy=57.88%]
# Epoch 87 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 287.76it/s, Test Loss=1.7260, Accuracy=52.71%]
# Epoch 88: 100%|██████████| 391/391 [00:03<00:00, 103.99it/s, Loss=1.5050, Accuracy=57.78%]
# Epoch 88 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 266.37it/s, Test Loss=1.7219, Accuracy=52.62%]
# Epoch 89: 100%|██████████| 391/391 [00:03<00:00, 104.94it/s, Loss=1.5054, Accuracy=58.04%]
# Epoch 89 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 290.63it/s, Test Loss=1.7211, Accuracy=52.80%]
# Epoch 90: 100%|██████████| 391/391 [00:03<00:00, 107.17it/s, Loss=1.4997, Accuracy=57.99%]
# Epoch 90 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 295.05it/s, Test Loss=1.7260, Accuracy=52.71%]
# Epoch 91: 100%|██████████| 391/391 [00:03<00:00, 107.08it/s, Loss=1.4967, Accuracy=58.13%]
# Epoch 91 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 309.17it/s, Test Loss=1.7220, Accuracy=52.65%]
# Epoch 92: 100%|██████████| 391/391 [00:03<00:00, 104.57it/s, Loss=1.5050, Accuracy=57.90%]
# Epoch 92 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 275.29it/s, Test Loss=1.7264, Accuracy=52.46%]
# Epoch 93: 100%|██████████| 391/391 [00:03<00:00, 107.07it/s, Loss=1.5022, Accuracy=57.97%]
# Epoch 93 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 266.77it/s, Test Loss=1.7232, Accuracy=52.61%]
# Epoch 94: 100%|██████████| 391/391 [00:03<00:00, 104.43it/s, Loss=1.5035, Accuracy=57.82%]
# Epoch 94 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 287.48it/s, Test Loss=1.7232, Accuracy=52.69%]
# Epoch 95: 100%|██████████| 391/391 [00:03<00:00, 105.39it/s, Loss=1.4986, Accuracy=58.23%]
# Epoch 95 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 266.23it/s, Test Loss=1.7227, Accuracy=52.68%]
# Epoch 96: 100%|██████████| 391/391 [00:03<00:00, 106.28it/s, Loss=1.5001, Accuracy=57.83%]
# Epoch 96 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 276.00it/s, Test Loss=1.7194, Accuracy=52.80%]
# Epoch 97: 100%|██████████| 391/391 [00:03<00:00, 105.80it/s, Loss=1.4970, Accuracy=58.21%]
# Epoch 97 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 255.20it/s, Test Loss=1.7251, Accuracy=52.55%]
# Epoch 98: 100%|██████████| 391/391 [00:03<00:00, 105.48it/s, Loss=1.4964, Accuracy=58.01%]
# Epoch 98 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 308.35it/s, Test Loss=1.7236, Accuracy=52.57%]
# Epoch 99: 100%|██████████| 391/391 [00:03<00:00, 105.18it/s, Loss=1.4998, Accuracy=58.04%]
# Epoch 99 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 309.44it/s, Test Loss=1.7253, Accuracy=52.56%]
# Epoch 100: 100%|██████████| 391/391 [00:03<00:00, 104.68it/s, Loss=1.5002, Accuracy=58.08%]
# Epoch 100 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 301.37it/s, Test Loss=1.7257, Accuracy=52.54%]
# Epoch 101: 100%|██████████| 391/391 [00:03<00:00, 106.76it/s, Loss=1.4985, Accuracy=57.92%]
# Epoch 101 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 319.70it/s, Test Loss=1.7217, Accuracy=52.78%]
# Epoch 102: 100%|██████████| 391/391 [00:03<00:00, 105.38it/s, Loss=1.4989, Accuracy=57.89%]
# Epoch 102 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 293.13it/s, Test Loss=1.7231, Accuracy=52.76%]
# Epoch 103: 100%|██████████| 391/391 [00:03<00:00, 103.67it/s, Loss=1.5030, Accuracy=57.96%]
# Epoch 103 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 312.70it/s, Test Loss=1.7214, Accuracy=52.81%]
# Epoch 104: 100%|██████████| 391/391 [00:03<00:00, 106.57it/s, Loss=1.4941, Accuracy=58.05%]
# Epoch 104 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 275.97it/s, Test Loss=1.7256, Accuracy=52.71%]
# Epoch 105: 100%|██████████| 391/391 [00:03<00:00, 105.55it/s, Loss=1.4970, Accuracy=58.12%]
# Epoch 105 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 271.77it/s, Test Loss=1.7231, Accuracy=52.57%]
# Epoch 106: 100%|██████████| 391/391 [00:03<00:00, 101.86it/s, Loss=1.4949, Accuracy=58.01%]
# Epoch 106 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 285.52it/s, Test Loss=1.7206, Accuracy=52.87%]
# Epoch 107: 100%|██████████| 391/391 [00:03<00:00, 106.87it/s, Loss=1.4999, Accuracy=57.80%]
# Epoch 107 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 275.69it/s, Test Loss=1.7187, Accuracy=52.73%]
# Epoch 108: 100%|██████████| 391/391 [00:03<00:00, 103.09it/s, Loss=1.5016, Accuracy=57.96%]
# Epoch 108 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 282.69it/s, Test Loss=1.7237, Accuracy=52.78%]
# Epoch 109: 100%|██████████| 391/391 [00:03<00:00, 103.01it/s, Loss=1.4992, Accuracy=57.88%]
# Epoch 109 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 308.79it/s, Test Loss=1.7235, Accuracy=52.78%]
# Epoch 110: 100%|██████████| 391/391 [00:03<00:00, 105.88it/s, Loss=1.4994, Accuracy=57.73%]
# Epoch 110 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 264.34it/s, Test Loss=1.7236, Accuracy=52.67%]
# Epoch 111: 100%|██████████| 391/391 [00:03<00:00, 105.16it/s, Loss=1.4983, Accuracy=58.14%]
# Epoch 111 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 300.64it/s, Test Loss=1.7250, Accuracy=52.55%]
# Epoch 112: 100%|██████████| 391/391 [00:03<00:00, 106.21it/s, Loss=1.5011, Accuracy=58.02%]
# Epoch 112 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 280.02it/s, Test Loss=1.7263, Accuracy=52.56%]
# Epoch 113: 100%|██████████| 391/391 [00:03<00:00, 109.46it/s, Loss=1.4992, Accuracy=58.13%]
# Epoch 113 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 311.01it/s, Test Loss=1.7212, Accuracy=52.73%]
# Epoch 114: 100%|██████████| 391/391 [00:03<00:00, 105.01it/s, Loss=1.4963, Accuracy=58.21%]
# Epoch 114 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 291.84it/s, Test Loss=1.7250, Accuracy=52.78%]
# Epoch 115: 100%|██████████| 391/391 [00:03<00:00, 106.73it/s, Loss=1.4981, Accuracy=58.16%]
# Epoch 115 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 297.27it/s, Test Loss=1.7216, Accuracy=52.66%]
# Epoch 116: 100%|██████████| 391/391 [00:03<00:00, 105.38it/s, Loss=1.5032, Accuracy=57.90%]
# Epoch 116 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 306.03it/s, Test Loss=1.7220, Accuracy=52.74%]
# Epoch 117: 100%|██████████| 391/391 [00:03<00:00, 106.79it/s, Loss=1.5015, Accuracy=57.84%]
# Epoch 117 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 304.36it/s, Test Loss=1.7274, Accuracy=52.69%]
# Epoch 118: 100%|██████████| 391/391 [00:03<00:00, 106.87it/s, Loss=1.5001, Accuracy=58.10%]
# Epoch 118 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 318.10it/s, Test Loss=1.7191, Accuracy=52.85%]
# Epoch 119: 100%|██████████| 391/391 [00:03<00:00, 105.16it/s, Loss=1.5022, Accuracy=57.92%]
# Epoch 119 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 284.95it/s, Test Loss=1.7219, Accuracy=52.79%]
# Epoch 120: 100%|██████████| 391/391 [00:03<00:00, 105.11it/s, Loss=1.4998, Accuracy=58.12%]
# Epoch 120 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 271.35it/s, Test Loss=1.7263, Accuracy=52.69%]
# Epoch 121: 100%|██████████| 391/391 [00:03<00:00, 105.99it/s, Loss=1.5039, Accuracy=58.00%]
# Epoch 121 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 297.53it/s, Test Loss=1.7274, Accuracy=52.47%]
# Epoch 122: 100%|██████████| 391/391 [00:03<00:00, 106.16it/s, Loss=1.4976, Accuracy=58.00%]
# Epoch 122 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 316.89it/s, Test Loss=1.7247, Accuracy=52.64%]
# Epoch 123: 100%|██████████| 391/391 [00:03<00:00, 105.91it/s, Loss=1.4979, Accuracy=57.90%]
# Epoch 123 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.25it/s, Test Loss=1.7219, Accuracy=52.70%]
# Epoch 124: 100%|██████████| 391/391 [00:03<00:00, 105.07it/s, Loss=1.5000, Accuracy=58.03%]
# Epoch 124 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 311.93it/s, Test Loss=1.7200, Accuracy=52.78%]
# Epoch 125: 100%|██████████| 391/391 [00:03<00:00, 103.62it/s, Loss=1.5010, Accuracy=58.04%]
# Epoch 125 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 269.95it/s, Test Loss=1.7241, Accuracy=52.63%]
# Epoch 126: 100%|██████████| 391/391 [00:03<00:00, 106.33it/s, Loss=1.4984, Accuracy=58.09%]
# Epoch 126 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 326.43it/s, Test Loss=1.7247, Accuracy=52.40%]
# Epoch 127: 100%|██████████| 391/391 [00:03<00:00, 106.87it/s, Loss=1.4951, Accuracy=58.14%]
# Epoch 127 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 287.21it/s, Test Loss=1.7228, Accuracy=52.61%]
# Epoch 128: 100%|██████████| 391/391 [00:03<00:00, 106.93it/s, Loss=1.4985, Accuracy=57.87%]
# Epoch 128 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 271.29it/s, Test Loss=1.7274, Accuracy=52.32%]
# Epoch 129: 100%|██████████| 391/391 [00:03<00:00, 105.11it/s, Loss=1.4968, Accuracy=58.10%]
# Epoch 129 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.19it/s, Test Loss=1.7250, Accuracy=52.65%]
# Epoch 130: 100%|██████████| 391/391 [00:03<00:00, 107.01it/s, Loss=1.4993, Accuracy=58.16%]
# Epoch 130 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 293.43it/s, Test Loss=1.7239, Accuracy=52.56%]
# Epoch 131: 100%|██████████| 391/391 [00:03<00:00, 105.04it/s, Loss=1.5010, Accuracy=58.06%]
# Epoch 131 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 281.40it/s, Test Loss=1.7232, Accuracy=52.56%]
# Epoch 132: 100%|██████████| 391/391 [00:03<00:00, 104.86it/s, Loss=1.4989, Accuracy=58.03%]
# Epoch 132 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 282.96it/s, Test Loss=1.7260, Accuracy=52.36%]
# Epoch 133: 100%|██████████| 391/391 [00:03<00:00, 105.92it/s, Loss=1.4960, Accuracy=57.78%]
# Epoch 133 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 322.50it/s, Test Loss=1.7245, Accuracy=52.77%]
# Epoch 134: 100%|██████████| 391/391 [00:03<00:00, 104.36it/s, Loss=1.4974, Accuracy=58.01%]
# Epoch 134 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 267.90it/s, Test Loss=1.7211, Accuracy=52.64%]
# Epoch 135: 100%|██████████| 391/391 [00:03<00:00, 104.25it/s, Loss=1.4988, Accuracy=57.89%]
# Epoch 135 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 281.11it/s, Test Loss=1.7228, Accuracy=52.52%]
# Epoch 136: 100%|██████████| 391/391 [00:03<00:00, 103.55it/s, Loss=1.5010, Accuracy=58.05%]
# Epoch 136 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 269.53it/s, Test Loss=1.7267, Accuracy=52.55%]
# Epoch 137: 100%|██████████| 391/391 [00:03<00:00, 103.96it/s, Loss=1.4981, Accuracy=58.15%]
# Epoch 137 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 265.69it/s, Test Loss=1.7221, Accuracy=52.84%]
# Epoch 138: 100%|██████████| 391/391 [00:03<00:00, 103.87it/s, Loss=1.5020, Accuracy=57.83%]
# Epoch 138 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 298.19it/s, Test Loss=1.7277, Accuracy=52.58%]
# Epoch 139: 100%|██████████| 391/391 [00:03<00:00, 105.82it/s, Loss=1.4970, Accuracy=58.17%]
# Epoch 139 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 295.98it/s, Test Loss=1.7222, Accuracy=52.83%]
# Epoch 140: 100%|██████████| 391/391 [00:03<00:00, 106.30it/s, Loss=1.5008, Accuracy=57.97%]
# Epoch 140 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 257.24it/s, Test Loss=1.7214, Accuracy=52.75%]
# Epoch 141: 100%|██████████| 391/391 [00:03<00:00, 102.69it/s, Loss=1.4935, Accuracy=58.24%]
# Epoch 141 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 286.80it/s, Test Loss=1.7257, Accuracy=52.64%]
# Epoch 142: 100%|██████████| 391/391 [00:03<00:00, 106.02it/s, Loss=1.5009, Accuracy=57.88%]
# Epoch 142 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 291.24it/s, Test Loss=1.7224, Accuracy=52.59%]
# Epoch 143: 100%|██████████| 391/391 [00:03<00:00, 104.73it/s, Loss=1.4982, Accuracy=58.01%]
# Epoch 143 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 291.30it/s, Test Loss=1.7261, Accuracy=52.69%]
# Epoch 144: 100%|██████████| 391/391 [00:03<00:00, 105.72it/s, Loss=1.4998, Accuracy=58.00%]
# Epoch 144 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 284.29it/s, Test Loss=1.7274, Accuracy=52.60%]
# Epoch 145: 100%|██████████| 391/391 [00:03<00:00, 104.23it/s, Loss=1.5019, Accuracy=57.93%]
# Epoch 145 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 330.38it/s, Test Loss=1.7228, Accuracy=52.68%]
# Epoch 146: 100%|██████████| 391/391 [00:03<00:00, 106.06it/s, Loss=1.5007, Accuracy=57.96%]
# Epoch 146 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 312.87it/s, Test Loss=1.7252, Accuracy=52.53%]
# Epoch 147: 100%|██████████| 391/391 [00:03<00:00, 104.91it/s, Loss=1.5003, Accuracy=58.06%]
# Epoch 147 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 306.01it/s, Test Loss=1.7195, Accuracy=52.64%]
# Epoch 148: 100%|██████████| 391/391 [00:03<00:00, 104.93it/s, Loss=1.5012, Accuracy=58.18%]
# Epoch 148 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 282.23it/s, Test Loss=1.7229, Accuracy=52.62%]
# Epoch 149: 100%|██████████| 391/391 [00:03<00:00, 104.87it/s, Loss=1.4955, Accuracy=58.10%]
# Epoch 149 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 308.05it/s, Test Loss=1.7203, Accuracy=52.73%]
# Training MobileNet and ResNet32 with DML...
# Epoch 0: 100%|██████████| 391/391 [00:06<00:00, 61.78it/s, MobileNet Loss=4.2244, ResNet32 Loss=4.1053, MobileNet Acc=4.76%, ResNet32 Acc=6.76%]
# Epoch 0 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 307.31it/s, Test Loss=3.7796, Accuracy=11.09%]
# Epoch 1: 100%|██████████| 391/391 [00:06<00:00, 60.95it/s, MobileNet Loss=3.8250, ResNet32 Loss=3.6699, MobileNet Acc=9.94%, ResNet32 Acc=12.96%]
# Epoch 1 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 303.58it/s, Test Loss=3.5173, Accuracy=15.44%]
# Epoch 2: 100%|██████████| 391/391 [00:06<00:00, 62.15it/s, MobileNet Loss=3.6291, ResNet32 Loss=3.4068, MobileNet Acc=12.94%, ResNet32 Acc=17.96%]
# Epoch 2 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.71it/s, Test Loss=3.2261, Accuracy=21.14%]
# Epoch 3: 100%|██████████| 391/391 [00:06<00:00, 61.57it/s, MobileNet Loss=3.4549, ResNet32 Loss=3.1985, MobileNet Acc=16.05%, ResNet32 Acc=22.03%]
# Epoch 3 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 267.67it/s, Test Loss=3.1204, Accuracy=22.49%]
# Epoch 4: 100%|██████████| 391/391 [00:06<00:00, 62.94it/s, MobileNet Loss=3.2857, ResNet32 Loss=3.0218, MobileNet Acc=19.03%, ResNet32 Acc=25.44%]
# Epoch 4 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 289.73it/s, Test Loss=2.8902, Accuracy=26.62%]
# Epoch 5: 100%|██████████| 391/391 [00:06<00:00, 61.47it/s, MobileNet Loss=3.1223, ResNet32 Loss=2.8583, MobileNet Acc=22.17%, ResNet32 Acc=28.72%]
# Epoch 5 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 289.45it/s, Test Loss=2.7735, Accuracy=30.06%]
# Epoch 6: 100%|██████████| 391/391 [00:06<00:00, 61.94it/s, MobileNet Loss=2.9929, ResNet32 Loss=2.7296, MobileNet Acc=24.61%, ResNet32 Acc=30.98%]
# Epoch 6 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 271.80it/s, Test Loss=2.6689, Accuracy=31.14%]
# Epoch 7: 100%|██████████| 391/391 [00:06<00:00, 62.43it/s, MobileNet Loss=2.8801, ResNet32 Loss=2.6190, MobileNet Acc=26.65%, ResNet32 Acc=33.16%]
# Epoch 7 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 302.72it/s, Test Loss=2.5949, Accuracy=32.48%]
# Epoch 8: 100%|██████████| 391/391 [00:06<00:00, 61.64it/s, MobileNet Loss=2.7860, ResNet32 Loss=2.5195, MobileNet Acc=28.37%, ResNet32 Acc=35.22%]
# Epoch 8 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 275.22it/s, Test Loss=2.5932, Accuracy=32.53%]
# Epoch 9: 100%|██████████| 391/391 [00:06<00:00, 60.67it/s, MobileNet Loss=2.7094, ResNet32 Loss=2.4436, MobileNet Acc=29.95%, ResNet32 Acc=36.91%]
# Epoch 9 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 308.17it/s, Test Loss=2.4138, Accuracy=36.23%]
# Epoch 10: 100%|██████████| 391/391 [00:06<00:00, 62.34it/s, MobileNet Loss=2.6385, ResNet32 Loss=2.3607, MobileNet Acc=31.60%, ResNet32 Acc=38.82%]
# Epoch 10 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.91it/s, Test Loss=2.3488, Accuracy=37.76%]
# Epoch 11: 100%|██████████| 391/391 [00:06<00:00, 61.49it/s, MobileNet Loss=2.5755, ResNet32 Loss=2.3010, MobileNet Acc=32.78%, ResNet32 Acc=39.94%]
# Epoch 11 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 302.35it/s, Test Loss=2.3258, Accuracy=38.60%]
# Epoch 12: 100%|██████████| 391/391 [00:06<00:00, 61.47it/s, MobileNet Loss=2.5181, ResNet32 Loss=2.2453, MobileNet Acc=33.96%, ResNet32 Acc=40.92%]
# Epoch 12 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 299.77it/s, Test Loss=2.2254, Accuracy=40.11%]
# Epoch 13: 100%|██████████| 391/391 [00:06<00:00, 62.13it/s, MobileNet Loss=2.4717, ResNet32 Loss=2.1973, MobileNet Acc=35.21%, ResNet32 Acc=42.23%]
# Epoch 13 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 268.27it/s, Test Loss=2.1732, Accuracy=41.71%]
# Epoch 14: 100%|██████████| 391/391 [00:06<00:00, 61.84it/s, MobileNet Loss=2.4195, ResNet32 Loss=2.1437, MobileNet Acc=36.13%, ResNet32 Acc=43.50%]
# Epoch 14 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 287.99it/s, Test Loss=2.1626, Accuracy=41.92%]
# Epoch 15: 100%|██████████| 391/391 [00:06<00:00, 62.77it/s, MobileNet Loss=2.3861, ResNet32 Loss=2.1061, MobileNet Acc=36.61%, ResNet32 Acc=44.26%]
# Epoch 15 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 306.31it/s, Test Loss=2.0765, Accuracy=44.26%]
# Epoch 16: 100%|██████████| 391/391 [00:06<00:00, 61.43it/s, MobileNet Loss=2.3465, ResNet32 Loss=2.0678, MobileNet Acc=37.56%, ResNet32 Acc=45.15%]
# Epoch 16 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 302.87it/s, Test Loss=2.1026, Accuracy=43.13%]
# Epoch 17: 100%|██████████| 391/391 [00:06<00:00, 62.57it/s, MobileNet Loss=2.3093, ResNet32 Loss=2.0293, MobileNet Acc=38.25%, ResNet32 Acc=46.18%]
# Epoch 17 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 316.99it/s, Test Loss=2.0372, Accuracy=44.85%]
# Epoch 18: 100%|██████████| 391/391 [00:06<00:00, 61.20it/s, MobileNet Loss=2.2778, ResNet32 Loss=1.9986, MobileNet Acc=39.23%, ResNet32 Acc=47.06%]
# Epoch 18 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 291.40it/s, Test Loss=2.0314, Accuracy=44.60%]
# Epoch 19: 100%|██████████| 391/391 [00:06<00:00, 61.98it/s, MobileNet Loss=2.2453, ResNet32 Loss=1.9706, MobileNet Acc=39.79%, ResNet32 Acc=47.50%]
# Epoch 19 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 277.50it/s, Test Loss=2.0003, Accuracy=45.48%]
# Epoch 20: 100%|██████████| 391/391 [00:06<00:00, 61.79it/s, MobileNet Loss=2.2128, ResNet32 Loss=1.9379, MobileNet Acc=40.67%, ResNet32 Acc=48.25%]
# Epoch 20 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 312.01it/s, Test Loss=1.9836, Accuracy=46.02%]
# Epoch 21: 100%|██████████| 391/391 [00:06<00:00, 61.73it/s, MobileNet Loss=2.1791, ResNet32 Loss=1.9142, MobileNet Acc=41.49%, ResNet32 Acc=48.87%]
# Epoch 21 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 293.02it/s, Test Loss=1.9340, Accuracy=47.12%]
# Epoch 22: 100%|██████████| 391/391 [00:06<00:00, 61.99it/s, MobileNet Loss=2.1511, ResNet32 Loss=1.8849, MobileNet Acc=42.15%, ResNet32 Acc=49.57%]
# Epoch 22 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 332.21it/s, Test Loss=1.9136, Accuracy=47.78%]
# Epoch 23: 100%|██████████| 391/391 [00:06<00:00, 62.76it/s, MobileNet Loss=2.1252, ResNet32 Loss=1.8628, MobileNet Acc=42.63%, ResNet32 Acc=49.84%]
# Epoch 23 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 287.95it/s, Test Loss=1.9793, Accuracy=46.29%]
# Epoch 24: 100%|██████████| 391/391 [00:06<00:00, 61.77it/s, MobileNet Loss=2.0945, ResNet32 Loss=1.8327, MobileNet Acc=43.38%, ResNet32 Acc=50.79%]
# Epoch 24 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 313.62it/s, Test Loss=1.8903, Accuracy=47.81%]
# Epoch 25: 100%|██████████| 391/391 [00:06<00:00, 61.27it/s, MobileNet Loss=2.0726, ResNet32 Loss=1.8163, MobileNet Acc=43.91%, ResNet32 Acc=50.99%]
# Epoch 25 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 288.76it/s, Test Loss=1.9585, Accuracy=46.28%]
# Epoch 26: 100%|██████████| 391/391 [00:06<00:00, 62.43it/s, MobileNet Loss=2.0502, ResNet32 Loss=1.7964, MobileNet Acc=44.70%, ResNet32 Acc=51.83%]
# Epoch 26 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 314.37it/s, Test Loss=1.7905, Accuracy=50.87%]
# Epoch 27: 100%|██████████| 391/391 [00:06<00:00, 60.60it/s, MobileNet Loss=2.0325, ResNet32 Loss=1.7751, MobileNet Acc=44.78%, ResNet32 Acc=52.21%]
# Epoch 27 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 287.95it/s, Test Loss=1.8011, Accuracy=49.80%]
# Epoch 28: 100%|██████████| 391/391 [00:06<00:00, 61.43it/s, MobileNet Loss=2.0079, ResNet32 Loss=1.7542, MobileNet Acc=45.62%, ResNet32 Acc=52.97%]
# Epoch 28 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 288.95it/s, Test Loss=1.7863, Accuracy=50.36%]
# Epoch 29: 100%|██████████| 391/391 [00:06<00:00, 61.69it/s, MobileNet Loss=1.9911, ResNet32 Loss=1.7385, MobileNet Acc=45.92%, ResNet32 Acc=52.77%]
# Epoch 29 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 303.50it/s, Test Loss=1.8175, Accuracy=49.57%]
# Epoch 30: 100%|██████████| 391/391 [00:06<00:00, 61.46it/s, MobileNet Loss=1.9105, ResNet32 Loss=1.6648, MobileNet Acc=47.97%, ResNet32 Acc=55.22%]
# Epoch 30 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 292.08it/s, Test Loss=1.6641, Accuracy=54.17%]
# Epoch 31: 100%|██████████| 391/391 [00:06<00:00, 61.81it/s, MobileNet Loss=1.8571, ResNet32 Loss=1.6146, MobileNet Acc=49.48%, ResNet32 Acc=56.78%]
# Epoch 31 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 302.90it/s, Test Loss=1.6371, Accuracy=55.05%]
# Epoch 32: 100%|██████████| 391/391 [00:06<00:00, 60.45it/s, MobileNet Loss=1.8417, ResNet32 Loss=1.5972, MobileNet Acc=49.88%, ResNet32 Acc=57.16%]
# Epoch 32 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 297.52it/s, Test Loss=1.6221, Accuracy=55.11%]
# Epoch 33: 100%|██████████| 391/391 [00:06<00:00, 61.87it/s, MobileNet Loss=1.8237, ResNet32 Loss=1.5790, MobileNet Acc=50.30%, ResNet32 Acc=57.70%]
# Epoch 33 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 313.16it/s, Test Loss=1.6143, Accuracy=55.27%]
# Epoch 34: 100%|██████████| 391/391 [00:06<00:00, 59.59it/s, MobileNet Loss=1.8204, ResNet32 Loss=1.5724, MobileNet Acc=50.09%, ResNet32 Acc=57.75%]
# Epoch 34 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 313.28it/s, Test Loss=1.6055, Accuracy=55.55%]
# Epoch 35: 100%|██████████| 391/391 [00:06<00:00, 61.10it/s, MobileNet Loss=1.8082, ResNet32 Loss=1.5605, MobileNet Acc=50.64%, ResNet32 Acc=58.56%]
# Epoch 35 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 285.95it/s, Test Loss=1.5978, Accuracy=55.70%]
# Epoch 36: 100%|██████████| 391/391 [00:06<00:00, 61.02it/s, MobileNet Loss=1.8032, ResNet32 Loss=1.5556, MobileNet Acc=50.40%, ResNet32 Acc=58.35%]
# Epoch 36 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.82it/s, Test Loss=1.5931, Accuracy=55.73%]
# Epoch 37: 100%|██████████| 391/391 [00:06<00:00, 62.01it/s, MobileNet Loss=1.7972, ResNet32 Loss=1.5461, MobileNet Acc=50.70%, ResNet32 Acc=58.84%]
# Epoch 37 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 287.96it/s, Test Loss=1.5921, Accuracy=55.99%]
# Epoch 38: 100%|██████████| 391/391 [00:06<00:00, 60.69it/s, MobileNet Loss=1.7933, ResNet32 Loss=1.5437, MobileNet Acc=50.90%, ResNet32 Acc=58.74%]
# Epoch 38 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 273.25it/s, Test Loss=1.5861, Accuracy=56.01%]
# Epoch 39: 100%|██████████| 391/391 [00:06<00:00, 62.23it/s, MobileNet Loss=1.7867, ResNet32 Loss=1.5361, MobileNet Acc=51.30%, ResNet32 Acc=58.83%]
# Epoch 39 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 271.30it/s, Test Loss=1.5831, Accuracy=56.17%]
# Epoch 40: 100%|██████████| 391/391 [00:06<00:00, 61.18it/s, MobileNet Loss=1.7836, ResNet32 Loss=1.5341, MobileNet Acc=50.91%, ResNet32 Acc=58.65%]
# Epoch 40 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 286.13it/s, Test Loss=1.5819, Accuracy=56.04%]
# Epoch 41: 100%|██████████| 391/391 [00:06<00:00, 61.03it/s, MobileNet Loss=1.7710, ResNet32 Loss=1.5277, MobileNet Acc=51.29%, ResNet32 Acc=59.11%]
# Epoch 41 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 320.59it/s, Test Loss=1.5766, Accuracy=56.30%]
# Epoch 42: 100%|██████████| 391/391 [00:06<00:00, 61.81it/s, MobileNet Loss=1.7710, ResNet32 Loss=1.5219, MobileNet Acc=50.99%, ResNet32 Acc=59.01%]
# Epoch 42 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 241.24it/s, Test Loss=1.5756, Accuracy=56.20%]
# Epoch 43: 100%|██████████| 391/391 [00:06<00:00, 60.78it/s, MobileNet Loss=1.7682, ResNet32 Loss=1.5208, MobileNet Acc=51.39%, ResNet32 Acc=59.20%]
# Epoch 43 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 290.55it/s, Test Loss=1.5693, Accuracy=56.25%]
# Epoch 44: 100%|██████████| 391/391 [00:06<00:00, 61.64it/s, MobileNet Loss=1.7706, ResNet32 Loss=1.5157, MobileNet Acc=51.33%, ResNet32 Acc=59.15%]
# Epoch 44 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 291.73it/s, Test Loss=1.5716, Accuracy=56.23%]
# Epoch 45: 100%|██████████| 391/391 [00:06<00:00, 61.45it/s, MobileNet Loss=1.7643, ResNet32 Loss=1.5105, MobileNet Acc=51.25%, ResNet32 Acc=59.27%]
# Epoch 45 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 293.62it/s, Test Loss=1.5677, Accuracy=56.54%]
# Epoch 46: 100%|██████████| 391/391 [00:06<00:00, 61.36it/s, MobileNet Loss=1.7564, ResNet32 Loss=1.5051, MobileNet Acc=51.55%, ResNet32 Acc=59.41%]
# Epoch 46 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 285.30it/s, Test Loss=1.5646, Accuracy=56.56%]
# Epoch 47: 100%|██████████| 391/391 [00:06<00:00, 61.52it/s, MobileNet Loss=1.7592, ResNet32 Loss=1.5075, MobileNet Acc=51.59%, ResNet32 Acc=59.17%]
# Epoch 47 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 261.83it/s, Test Loss=1.5636, Accuracy=56.31%]
# Epoch 48: 100%|██████████| 391/391 [00:06<00:00, 61.46it/s, MobileNet Loss=1.7563, ResNet32 Loss=1.5025, MobileNet Acc=51.54%, ResNet32 Acc=59.43%]
# Epoch 48 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.84it/s, Test Loss=1.5596, Accuracy=56.40%]
# Epoch 49: 100%|██████████| 391/391 [00:06<00:00, 60.65it/s, MobileNet Loss=1.7510, ResNet32 Loss=1.5000, MobileNet Acc=51.63%, ResNet32 Acc=59.54%]
# Epoch 49 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 317.61it/s, Test Loss=1.5613, Accuracy=56.42%]
# Epoch 50: 100%|██████████| 391/391 [00:06<00:00, 61.35it/s, MobileNet Loss=1.7514, ResNet32 Loss=1.4988, MobileNet Acc=51.59%, ResNet32 Acc=59.37%]
# Epoch 50 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 298.97it/s, Test Loss=1.5543, Accuracy=56.57%]
# Epoch 51: 100%|██████████| 391/391 [00:06<00:00, 60.60it/s, MobileNet Loss=1.7469, ResNet32 Loss=1.4936, MobileNet Acc=51.63%, ResNet32 Acc=59.55%]
# Epoch 51 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 249.45it/s, Test Loss=1.5541, Accuracy=56.85%]
# Epoch 52: 100%|██████████| 391/391 [00:06<00:00, 62.24it/s, MobileNet Loss=1.7411, ResNet32 Loss=1.4890, MobileNet Acc=51.71%, ResNet32 Acc=59.85%]
# Epoch 52 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 267.52it/s, Test Loss=1.5552, Accuracy=56.58%]
# Epoch 53: 100%|██████████| 391/391 [00:06<00:00, 61.17it/s, MobileNet Loss=1.7376, ResNet32 Loss=1.4856, MobileNet Acc=51.99%, ResNet32 Acc=59.84%]
# Epoch 53 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 298.28it/s, Test Loss=1.5545, Accuracy=56.47%]
# Epoch 54: 100%|██████████| 391/391 [00:06<00:00, 61.81it/s, MobileNet Loss=1.7416, ResNet32 Loss=1.4885, MobileNet Acc=51.85%, ResNet32 Acc=59.71%]
# Epoch 54 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 283.83it/s, Test Loss=1.5546, Accuracy=56.73%]
# Epoch 55: 100%|██████████| 391/391 [00:06<00:00, 60.70it/s, MobileNet Loss=1.7402, ResNet32 Loss=1.4852, MobileNet Acc=52.09%, ResNet32 Acc=59.67%]
# Epoch 55 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 272.29it/s, Test Loss=1.5487, Accuracy=56.57%]
# Epoch 56: 100%|██████████| 391/391 [00:06<00:00, 60.69it/s, MobileNet Loss=1.7313, ResNet32 Loss=1.4785, MobileNet Acc=52.21%, ResNet32 Acc=59.86%]
# Epoch 56 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 271.09it/s, Test Loss=1.5518, Accuracy=56.82%]
# Epoch 57: 100%|██████████| 391/391 [00:06<00:00, 61.80it/s, MobileNet Loss=1.7321, ResNet32 Loss=1.4815, MobileNet Acc=52.03%, ResNet32 Acc=59.72%]
# Epoch 57 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 299.85it/s, Test Loss=1.5491, Accuracy=56.73%]
# Epoch 58: 100%|██████████| 391/391 [00:06<00:00, 61.52it/s, MobileNet Loss=1.7302, ResNet32 Loss=1.4762, MobileNet Acc=52.03%, ResNet32 Acc=59.88%]
# Epoch 58 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 256.43it/s, Test Loss=1.5476, Accuracy=56.81%]
# Epoch 59: 100%|██████████| 391/391 [00:06<00:00, 60.52it/s, MobileNet Loss=1.7312, ResNet32 Loss=1.4750, MobileNet Acc=52.05%, ResNet32 Acc=59.97%]
# Epoch 59 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 267.37it/s, Test Loss=1.5459, Accuracy=56.88%]
# Epoch 60: 100%|██████████| 391/391 [00:06<00:00, 61.43it/s, MobileNet Loss=1.7281, ResNet32 Loss=1.4724, MobileNet Acc=52.26%, ResNet32 Acc=60.03%]
# Epoch 60 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 321.00it/s, Test Loss=1.5459, Accuracy=56.65%]
# Epoch 61: 100%|██████████| 391/391 [00:06<00:00, 60.54it/s, MobileNet Loss=1.7267, ResNet32 Loss=1.4721, MobileNet Acc=52.07%, ResNet32 Acc=59.93%]
# Epoch 61 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 273.30it/s, Test Loss=1.5446, Accuracy=56.69%]
# Epoch 62: 100%|██████████| 391/391 [00:06<00:00, 61.40it/s, MobileNet Loss=1.7249, ResNet32 Loss=1.4694, MobileNet Acc=52.19%, ResNet32 Acc=60.19%]
# Epoch 62 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 281.15it/s, Test Loss=1.5440, Accuracy=56.93%]
# Epoch 63: 100%|██████████| 391/391 [00:06<00:00, 61.23it/s, MobileNet Loss=1.7284, ResNet32 Loss=1.4706, MobileNet Acc=52.07%, ResNet32 Acc=59.92%]
# Epoch 63 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 243.01it/s, Test Loss=1.5453, Accuracy=56.75%]
# ...
# Epoch 90: 100%|██████████| 391/391 [00:06<00:00, 59.60it/s, MobileNet Loss=1.7259, ResNet32 Loss=1.4701, MobileNet Acc=52.29%, ResNet32 Acc=60.05%]
# Epoch 90 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 260.31it/s, Test Loss=1.5449, Accuracy=56.79%]
# Epoch 91: 100%|██████████| 391/391 [00:06<00:00, 60.32it/s, MobileNet Loss=1.7247, ResNet32 Loss=1.4705, MobileNet Acc=52.10%, ResNet32 Acc=59.86%]
# Epoch 91 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 268.61it/s, Test Loss=1.5426, Accuracy=56.72%]
# Epoch 92: 100%|██████████| 391/391 [00:06<00:00, 60.36it/s, MobileNet Loss=1.7250, ResNet32 Loss=1.4697, MobileNet Acc=52.18%, ResNet32 Acc=60.06%]
# Epoch 92 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 258.15it/s, Test Loss=1.5447, Accuracy=56.82%]
# Epoch 93: 100%|██████████| 391/391 [00:06<00:00, 60.24it/s, MobileNet Loss=1.7241, ResNet32 Loss=1.4711, MobileNet Acc=52.18%, ResNet32 Acc=60.09%]
# Epoch 93 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 259.73it/s, Test Loss=1.5456, Accuracy=56.84%]
# Epoch 94: 100%|██████████| 391/391 [00:06<00:00, 60.64it/s, MobileNet Loss=1.7243, ResNet32 Loss=1.4705, MobileNet Acc=52.20%, ResNet32 Acc=60.05%]
# Epoch 94 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 281.88it/s, Test Loss=1.5444, Accuracy=56.86%]
# Epoch 95: 100%|██████████| 391/391 [00:06<00:00, 62.08it/s, MobileNet Loss=1.7293, ResNet32 Loss=1.4716, MobileNet Acc=51.96%, ResNet32 Acc=59.98%]
# Epoch 95 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.84it/s, Test Loss=1.5432, Accuracy=56.79%]
# Epoch 96: 100%|██████████| 391/391 [00:06<00:00, 60.80it/s, MobileNet Loss=1.7223, ResNet32 Loss=1.4697, MobileNet Acc=52.44%, ResNet32 Acc=60.10%]
# Epoch 96 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 296.63it/s, Test Loss=1.5442, Accuracy=56.78%]
# Epoch 97: 100%|██████████| 391/391 [00:06<00:00, 60.68it/s, MobileNet Loss=1.7231, ResNet32 Loss=1.4712, MobileNet Acc=52.34%, ResNet32 Acc=60.11%]
# Epoch 97 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 250.90it/s, Test Loss=1.5450, Accuracy=56.89%]
# Epoch 98: 100%|██████████| 391/391 [00:06<00:00, 59.25it/s, MobileNet Loss=1.7292, ResNet32 Loss=1.4723, MobileNet Acc=52.24%, ResNet32 Acc=59.94%]
# Epoch 98 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 285.39it/s, Test Loss=1.5446, Accuracy=56.61%]
# Epoch 99: 100%|██████████| 391/391 [00:06<00:00, 60.30it/s, MobileNet Loss=1.7266, ResNet32 Loss=1.4708, MobileNet Acc=52.22%, ResNet32 Acc=60.06%]
# Epoch 99 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 255.08it/s, Test Loss=1.5436, Accuracy=56.70%]
# Epoch 100: 100%|██████████| 391/391 [00:06<00:00, 60.76it/s, MobileNet Loss=1.7238, ResNet32 Loss=1.4701, MobileNet Acc=52.39%, ResNet32 Acc=60.06%]
# Epoch 100 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 278.50it/s, Test Loss=1.5447, Accuracy=56.64%]
# Epoch 101: 100%|██████████| 391/391 [00:06<00:00, 60.68it/s, MobileNet Loss=1.7264, ResNet32 Loss=1.4743, MobileNet Acc=52.30%, ResNet32 Acc=60.00%]
# Epoch 101 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 293.45it/s, Test Loss=1.5431, Accuracy=56.86%]
# Epoch 102: 100%|██████████| 391/391 [00:06<00:00, 60.66it/s, MobileNet Loss=1.7311, ResNet32 Loss=1.4748, MobileNet Acc=52.16%, ResNet32 Acc=59.91%]
# Epoch 102 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 254.61it/s, Test Loss=1.5454, Accuracy=56.61%]
# Epoch 103: 100%|██████████| 391/391 [00:06<00:00, 60.07it/s, MobileNet Loss=1.7254, ResNet32 Loss=1.4728, MobileNet Acc=52.19%, ResNet32 Acc=60.10%]
# Epoch 103 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 277.54it/s, Test Loss=1.5445, Accuracy=56.86%]
# Epoch 104: 100%|██████████| 391/391 [00:06<00:00, 60.28it/s, MobileNet Loss=1.7250, ResNet32 Loss=1.4754, MobileNet Acc=52.27%, ResNet32 Acc=59.95%]
# Epoch 104 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 253.93it/s, Test Loss=1.5444, Accuracy=56.77%]
# Epoch 105: 100%|██████████| 391/391 [00:06<00:00, 60.67it/s, MobileNet Loss=1.7239, ResNet32 Loss=1.4683, MobileNet Acc=52.25%, ResNet32 Acc=59.90%]
# Epoch 105 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 282.92it/s, Test Loss=1.5426, Accuracy=56.96%]
# Epoch 106: 100%|██████████| 391/391 [00:06<00:00, 60.64it/s, MobileNet Loss=1.7247, ResNet32 Loss=1.4692, MobileNet Acc=52.16%, ResNet32 Acc=60.02%]
# Epoch 106 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 263.48it/s, Test Loss=1.5457, Accuracy=56.67%]
# Epoch 107: 100%|██████████| 391/391 [00:06<00:00, 61.07it/s, MobileNet Loss=1.7241, ResNet32 Loss=1.4716, MobileNet Acc=52.17%, ResNet32 Acc=59.89%]
# Epoch 107 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 292.60it/s, Test Loss=1.5443, Accuracy=56.85%]
# Epoch 108: 100%|██████████| 391/391 [00:06<00:00, 59.80it/s, MobileNet Loss=1.7218, ResNet32 Loss=1.4704, MobileNet Acc=52.32%, ResNet32 Acc=59.88%]
# Epoch 108 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 274.96it/s, Test Loss=1.5479, Accuracy=56.78%]
# Epoch 109: 100%|██████████| 391/391 [00:06<00:00, 61.04it/s, MobileNet Loss=1.7221, ResNet32 Loss=1.4688, MobileNet Acc=52.27%, ResNet32 Acc=59.96%]
# Epoch 109 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 279.83it/s, Test Loss=1.5456, Accuracy=56.93%]
# Epoch 110: 100%|██████████| 391/391 [00:06<00:00, 60.53it/s, MobileNet Loss=1.7280, ResNet32 Loss=1.4715, MobileNet Acc=52.26%, ResNet32 Acc=60.11%]
# Epoch 110 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 289.81it/s, Test Loss=1.5441, Accuracy=56.78%]
# Epoch 111: 100%|██████████| 391/391 [00:06<00:00, 61.83it/s, MobileNet Loss=1.7309, ResNet32 Loss=1.4721, MobileNet Acc=52.03%, ResNet32 Acc=60.06%]
# Epoch 111 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 272.67it/s, Test Loss=1.5444, Accuracy=56.96%]
# Epoch 112: 100%|██████████| 391/391 [00:06<00:00, 60.16it/s, MobileNet Loss=1.7250, ResNet32 Loss=1.4694, MobileNet Acc=52.38%, ResNet32 Acc=60.09%]
# Epoch 112 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 251.09it/s, Test Loss=1.5437, Accuracy=56.87%]
# Epoch 113: 100%|██████████| 391/391 [00:06<00:00, 59.21it/s, MobileNet Loss=1.7265, ResNet32 Loss=1.4688, MobileNet Acc=51.99%, ResNet32 Acc=59.94%]
# Epoch 113 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 270.35it/s, Test Loss=1.5444, Accuracy=56.92%]
# Epoch 114: 100%|██████████| 391/391 [00:06<00:00, 61.16it/s, MobileNet Loss=1.7259, ResNet32 Loss=1.4698, MobileNet Acc=52.33%, ResNet32 Acc=60.13%]
# Epoch 114 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 299.44it/s, Test Loss=1.5464, Accuracy=56.72%]
# Epoch 115: 100%|██████████| 391/391 [00:06<00:00, 60.50it/s, MobileNet Loss=1.7262, ResNet32 Loss=1.4695, MobileNet Acc=52.20%, ResNet32 Acc=60.14%]
# Epoch 115 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 249.70it/s, Test Loss=1.5417, Accuracy=56.94%]
# Epoch 116: 100%|██████████| 391/391 [00:06<00:00, 59.92it/s, MobileNet Loss=1.7249, ResNet32 Loss=1.4708, MobileNet Acc=52.40%, ResNet32 Acc=60.10%]
# Epoch 116 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 258.38it/s, Test Loss=1.5457, Accuracy=56.79%]
# Epoch 117: 100%|██████████| 391/391 [00:06<00:00, 61.08it/s, MobileNet Loss=1.7260, ResNet32 Loss=1.4715, MobileNet Acc=52.23%, ResNet32 Acc=60.01%]
# Epoch 117 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 246.45it/s, Test Loss=1.5458, Accuracy=56.71%]
# Epoch 118: 100%|██████████| 391/391 [00:06<00:00, 59.78it/s, MobileNet Loss=1.7242, ResNet32 Loss=1.4690, MobileNet Acc=52.49%, ResNet32 Acc=59.98%]
# Epoch 118 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 276.53it/s, Test Loss=1.5439, Accuracy=56.88%]
# Epoch 119: 100%|██████████| 391/391 [00:06<00:00, 59.82it/s, MobileNet Loss=1.7231, ResNet32 Loss=1.4689, MobileNet Acc=52.35%, ResNet32 Acc=60.19%]
# Epoch 119 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 286.64it/s, Test Loss=1.5456, Accuracy=56.53%]
# Epoch 120: 100%|██████████| 391/391 [00:06<00:00, 61.13it/s, MobileNet Loss=1.7238, ResNet32 Loss=1.4708, MobileNet Acc=52.38%, ResNet32 Acc=59.97%]
# Epoch 120 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 240.63it/s, Test Loss=1.5456, Accuracy=56.76%]
# Epoch 121: 100%|██████████| 391/391 [00:06<00:00, 59.81it/s, MobileNet Loss=1.7247, ResNet32 Loss=1.4708, MobileNet Acc=52.10%, ResNet32 Acc=59.96%]
# Epoch 121 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 249.82it/s, Test Loss=1.5440, Accuracy=56.88%]
# Epoch 122: 100%|██████████| 391/391 [00:06<00:00, 60.14it/s, MobileNet Loss=1.7293, ResNet32 Loss=1.4702, MobileNet Acc=52.09%, ResNet32 Acc=60.07%]
# Epoch 122 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 259.85it/s, Test Loss=1.5472, Accuracy=56.77%]
# Epoch 123: 100%|██████████| 391/391 [00:06<00:00, 60.30it/s, MobileNet Loss=1.7266, ResNet32 Loss=1.4737, MobileNet Acc=52.38%, ResNet32 Acc=59.82%]
# Epoch 123 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 253.14it/s, Test Loss=1.5456, Accuracy=56.76%]
# Epoch 124: 100%|██████████| 391/391 [00:06<00:00, 60.22it/s, MobileNet Loss=1.7255, ResNet32 Loss=1.4711, MobileNet Acc=52.20%, ResNet32 Acc=60.11%]
# Epoch 124 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 295.59it/s, Test Loss=1.5445, Accuracy=56.77%]
# Epoch 125: 100%|██████████| 391/391 [00:06<00:00, 60.58it/s, MobileNet Loss=1.7231, ResNet32 Loss=1.4721, MobileNet Acc=52.44%, ResNet32 Acc=60.12%]
# Epoch 125 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 263.25it/s, Test Loss=1.5459, Accuracy=56.70%]
# Epoch 126: 100%|██████████| 391/391 [00:06<00:00, 60.38it/s, MobileNet Loss=1.7253, ResNet32 Loss=1.4710, MobileNet Acc=52.07%, ResNet32 Acc=59.89%]
# Epoch 126 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 271.37it/s, Test Loss=1.5481, Accuracy=56.71%]
# Epoch 127: 100%|██████████| 391/391 [00:06<00:00, 61.22it/s, MobileNet Loss=1.7257, ResNet32 Loss=1.4707, MobileNet Acc=52.25%, ResNet32 Acc=60.05%]
# Epoch 127 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 311.67it/s, Test Loss=1.5443, Accuracy=56.94%]
# Epoch 128: 100%|██████████| 391/391 [00:06<00:00, 61.20it/s, MobileNet Loss=1.7250, ResNet32 Loss=1.4728, MobileNet Acc=52.25%, ResNet32 Acc=59.96%]
# Epoch 128 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 249.11it/s, Test Loss=1.5433, Accuracy=56.94%]
# Epoch 129: 100%|██████████| 391/391 [00:06<00:00, 59.09it/s, MobileNet Loss=1.7263, ResNet32 Loss=1.4713, MobileNet Acc=52.12%, ResNet32 Acc=60.02%]
# Epoch 129 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 263.70it/s, Test Loss=1.5447, Accuracy=57.04%]
# Epoch 130: 100%|██████████| 391/391 [00:06<00:00, 59.59it/s, MobileNet Loss=1.7259, ResNet32 Loss=1.4730, MobileNet Acc=52.30%, ResNet32 Acc=59.94%]
# Epoch 130 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 297.28it/s, Test Loss=1.5473, Accuracy=56.72%]
# Epoch 131: 100%|██████████| 391/391 [00:06<00:00, 59.87it/s, MobileNet Loss=1.7280, ResNet32 Loss=1.4726, MobileNet Acc=51.97%, ResNet32 Acc=59.80%]
# Epoch 131 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 293.76it/s, Test Loss=1.5456, Accuracy=56.87%]
# Epoch 132: 100%|██████████| 391/391 [00:06<00:00, 60.55it/s, MobileNet Loss=1.7272, ResNet32 Loss=1.4728, MobileNet Acc=52.28%, ResNet32 Acc=60.07%]
# Epoch 132 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 293.49it/s, Test Loss=1.5469, Accuracy=56.84%]
# Epoch 133: 100%|██████████| 391/391 [00:06<00:00, 60.17it/s, MobileNet Loss=1.7265, ResNet32 Loss=1.4714, MobileNet Acc=52.36%, ResNet32 Acc=60.07%]
# Epoch 133 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 302.57it/s, Test Loss=1.5463, Accuracy=56.83%]
# Epoch 134: 100%|██████████| 391/391 [00:06<00:00, 59.61it/s, MobileNet Loss=1.7250, ResNet32 Loss=1.4721, MobileNet Acc=52.21%, ResNet32 Acc=59.97%]
# Epoch 134 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 294.56it/s, Test Loss=1.5407, Accuracy=56.85%]
# Epoch 135: 100%|██████████| 391/391 [00:06<00:00, 60.02it/s, MobileNet Loss=1.7259, ResNet32 Loss=1.4691, MobileNet Acc=52.11%, ResNet32 Acc=59.98%]
# Epoch 135 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 242.26it/s, Test Loss=1.5423, Accuracy=56.95%]
# Epoch 136: 100%|██████████| 391/391 [00:06<00:00, 60.36it/s, MobileNet Loss=1.7272, ResNet32 Loss=1.4722, MobileNet Acc=52.16%, ResNet32 Acc=60.24%]
# Epoch 136 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 273.36it/s, Test Loss=1.5432, Accuracy=56.92%]
# Epoch 137: 100%|██████████| 391/391 [00:06<00:00, 59.42it/s, MobileNet Loss=1.7290, ResNet32 Loss=1.4738, MobileNet Acc=52.27%, ResNet32 Acc=60.00%]
# Epoch 137 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 265.71it/s, Test Loss=1.5426, Accuracy=56.93%]
# Epoch 138: 100%|██████████| 391/391 [00:06<00:00, 61.25it/s, MobileNet Loss=1.7273, ResNet32 Loss=1.4698, MobileNet Acc=52.17%, ResNet32 Acc=60.06%]
# Epoch 138 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 267.58it/s, Test Loss=1.5430, Accuracy=56.75%]
# Epoch 139: 100%|██████████| 391/391 [00:06<00:00, 59.59it/s, MobileNet Loss=1.7268, ResNet32 Loss=1.4729, MobileNet Acc=52.28%, ResNet32 Acc=59.77%]
# Epoch 139 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 254.69it/s, Test Loss=1.5462, Accuracy=56.83%]
# Epoch 140: 100%|██████████| 391/391 [00:06<00:00, 59.93it/s, MobileNet Loss=1.7307, ResNet32 Loss=1.4740, MobileNet Acc=52.21%, ResNet32 Acc=59.91%]
# Epoch 140 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 278.84it/s, Test Loss=1.5451, Accuracy=56.89%]
# Epoch 141: 100%|██████████| 391/391 [00:06<00:00, 60.61it/s, MobileNet Loss=1.7234, ResNet32 Loss=1.4698, MobileNet Acc=52.47%, ResNet32 Acc=60.17%]
# Epoch 141 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 295.59it/s, Test Loss=1.5452, Accuracy=56.64%]
# Epoch 142: 100%|██████████| 391/391 [00:06<00:00, 60.42it/s, MobileNet Loss=1.7260, ResNet32 Loss=1.4708, MobileNet Acc=52.04%, ResNet32 Acc=59.87%]
# Epoch 142 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 274.09it/s, Test Loss=1.5429, Accuracy=56.79%]
# Epoch 143: 100%|██████████| 391/391 [00:06<00:00, 60.76it/s, MobileNet Loss=1.7265, ResNet32 Loss=1.4719, MobileNet Acc=52.30%, ResNet32 Acc=59.94%]
# Epoch 143 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 289.80it/s, Test Loss=1.5439, Accuracy=56.94%]
# Epoch 144: 100%|██████████| 391/391 [00:06<00:00, 59.90it/s, MobileNet Loss=1.7230, ResNet32 Loss=1.4697, MobileNet Acc=52.18%, ResNet32 Acc=59.91%]
# Epoch 144 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 263.87it/s, Test Loss=1.5451, Accuracy=56.96%]
# Epoch 145: 100%|██████████| 391/391 [00:06<00:00, 60.31it/s, MobileNet Loss=1.7274, ResNet32 Loss=1.4710, MobileNet Acc=52.28%, ResNet32 Acc=60.04%]
# Epoch 145 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 262.22it/s, Test Loss=1.5431, Accuracy=56.80%]
# Epoch 146: 100%|██████████| 391/391 [00:06<00:00, 58.52it/s, MobileNet Loss=1.7247, ResNet32 Loss=1.4722, MobileNet Acc=52.33%, ResNet32 Acc=59.87%]
# Epoch 146 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 276.83it/s, Test Loss=1.5450, Accuracy=56.82%]
# Epoch 147: 100%|██████████| 391/391 [00:06<00:00, 59.57it/s, MobileNet Loss=1.7231, ResNet32 Loss=1.4696, MobileNet Acc=52.50%, ResNet32 Acc=60.03%]
# Epoch 147 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 256.40it/s, Test Loss=1.5435, Accuracy=57.02%]
# Epoch 148: 100%|██████████| 391/391 [00:06<00:00, 60.43it/s, MobileNet Loss=1.7222, ResNet32 Loss=1.4703, MobileNet Acc=52.36%, ResNet32 Acc=59.87%]
# Epoch 148 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 281.12it/s, Test Loss=1.5465, Accuracy=56.84%]
# Epoch 149: 100%|██████████| 391/391 [00:06<00:00, 60.74it/s, MobileNet Loss=1.7262, ResNet32 Loss=1.4711, MobileNet Acc=52.15%, ResNet32 Acc=60.01%]
# Epoch 149 [Testing ResNet32]: 100%|██████████| 100/100 [00:00<00:00, 290.07it/s, Test Loss=1.5462, Accuracy=56.77%]
# Accuracy Comparison:
# ResNet32 Independent: 52.73%
# ResNet32 after DML: 56.77%
